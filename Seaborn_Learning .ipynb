# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Line plot

# %%
var = pd.DataFrame({
    'var' : np.random.randn(20).cumsum(),
    'var1' : np.random.randn(20)

})
sns.lineplot(
    x = 'var',
    y = 'var1',
    data = var
)
plt.show()
# Out:
#          var      var1
# 0  -0.206621 -0.576833
# 1  -0.204300  0.515934
# 2  -0.871092 -0.948442
# 3  -0.468261 -0.964557
# 4  -0.172135 -0.635938
# 5  -0.992857  0.819174
# 6  -0.997207  0.447620
# 7   0.895701 -0.094199
# 8   0.996640  0.125483
# 9   0.225336  0.158605
# 10  0.576776  0.449375
# 11  0.979905  0.286649
# 12  0.913697  0.127267
# 13 -0.110516  0.802940
# 14 -0.881345  0.811259
# 15 -0.915530 -0.717325
# 16 -0.400351 -0.097815
# 17 -0.960346 -0.485367
# 18 -0.699789 -0.592119
# 19 -0.987522  0.571310

# %% [markdown]
# # HeatMap graph

# %%
var = np.linspace(1,10,20).reshape(4,5)
sns.heatmap(var)
# Out:
# <Axes: >
